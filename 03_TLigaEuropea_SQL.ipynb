# %% [markdown]
# <a href="https://colab.research.google.com/github/YilBC/TalentoYB/blob/main/03_TLigaEuropea_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# %%
#Cargar dataset desde drive
from google.colab import drive
drive.mount('/content/drive')

#ruta = '/content/drive/MyDrive/BOOTCAMP/'
#database = ruta + 'database.sqlite'
database = '/content/database.sqlite'

conn = sqlite3.connect(database)
print("Conexion exitosa")

print(database)

tables = pd.read_sql("""SELECT *
                     FROM sqlite_master
                     WHERE type='table';""",conn)

tables
# Out:
# Mounted at /content/drive
# Conexion exitosa
# /content/database.sqlite
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
query = """SELECT *
           FROM League;"""

leagues = pd.read_sql(query, conn)
leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
query = """SELECT id, player_name, birthday, height, weight
           FROM Player;"""

players = pd.read_sql(query, conn)
players
# Out:
#           id          player_name             birthday  height  weight
# 0          1   Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1          2      Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2          3          Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3          4        Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4          5         Aaron Hughes  1979-11-08 00:00:00  182.88     154
# ...      ...                  ...                  ...     ...     ...
# 11055  11071       Zoumana Camara  1979-04-03 00:00:00  182.88     168
# 11056  11072         Zsolt Laczko  1986-12-18 00:00:00  182.88     176
# 11057  11073            Zsolt Low  1979-04-29 00:00:00  180.34     154
# 11058  11074  Zurab Khizanishvili  1981-10-06 00:00:00  185.42     172
# 11059  11075   Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 5 columns]

# %%
query = """SELECT DISTINCT overall_rating
           FROM Player_Attributes;"""

overall_rating = pd.read_sql(query, conn)
overall_rating
# Out:
#     overall_rating
# 0             67.0
# 1             62.0
# 2             61.0
# 3             74.0
# 4             73.0
# ..             ...
# 57            33.0
# 58            36.0
# 59            37.0
# 60            35.0
# 61            94.0
#
# [62 rows x 1 columns]

# %%
query = """SELECT id, team_long_name
           FROM Team
           LIMIT 25;"""

teams = pd.read_sql(query, conn)
teams
# Out:
#       id        team_long_name
# 0      1              KRC Genk
# 1      2          Beerschot AC
# 2      3      SV Zulte-Waregem
# 3      4      Sporting Lokeren
# 4      5     KSV Cercle Brugge
# 5      6        RSC Anderlecht
# 6      7              KAA Gent
# 7      8             RAEC Mons
# 8      9         FCV Dender EH
# 9     10     Standard de Liège
# 10    11           KV Mechelen
# 11    12        Club Brugge KV
# 12    13         KSV Roeselare
# 13    14           KV Kortrijk
# 14    15                Tubize
# 15    16  Royal Excel Mouscron
# 16    17          KVC Westerlo
# 17    18    Sporting Charleroi
# 18   614     Sint-Truidense VV
# 19  1034             Lierse SK
# 20  1042             KAS Eupen
# 21  1513   Oud-Heverlee Leuven
# 22  2004      Waasland-Beveren
# 23  2476           KV Oostende
# 24  2510  Royal Excel Mouscron

# %%
query = """
SELECT COUNT(DISTINCT stage)
FROM Match;
"""

countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#    COUNT(DISTINCT stage)
# 0                     38

# %%
query = """
SELECT SUM(away_team_goal)
FROM Match;
"""

sum_awayteam = pd.read_sql(query, conn)
sum_awayteam
# Out:
#    SUM(away_team_goal)
# 0                30160

# %%
query = """
SELECT AVG(home_team_goal), AVG(away_team_goal)
FROM Match;
"""

avg_teamgoals = pd.read_sql(query, conn)
avg_teamgoals
# Out:
#    AVG(home_team_goal)  AVG(away_team_goal)
# 0             1.544594             1.160938

# %%
query = """
SELECT MAX(away_team_goal), away_team_api_id
FROM Match;
"""

max_teamgoals = pd.read_sql(query, conn)
max_teamgoals
# Out:
#    MAX(away_team_goal)  away_team_api_id
# 0                    9              9847

# %%
query = """
SELECT AVG(home_team_goal+away_team_goal)
FROM Match;
"""

avg_sum_goals = pd.read_sql(query, conn)
avg_sum_goals
# Out:
#    AVG(home_team_goal+away_team_goal)
# 0                            2.705531

# %%
query = """
SELECT season, home_team_goal, away_team_goal
FROM Match
WHERE away_team_goal >= 7;
"""

away_team_goals = pd.read_sql(query, conn)
away_team_goals
# Out:
#        season  home_team_goal  away_team_goal
# 0   2012/2013               1               7
# 1   2014/2015               1               7
# 2   2014/2015               2               7
# 3   2015/2016               0               9
# 4   2010/2011               1               8
# 5   2013/2014               0               7
# 6   2010/2011               0               7
# 7   2013/2014               0               7
# 8   2010/2011               0               8
# 9   2011/2012               0               7
# 10  2014/2015               0               8
# 11  2014/2015               2               8
# 12  2015/2016               0               8
# 13  2008/2009               1               7
# 14  2009/2010               1               7
# 15  2015/2016               0               7

# %%
query = """
SELECT id, buildUpPlayDribblingClass, buildUpPlaySpeedClass
FROM Team_Attributes
WHERE buildUpPlayDribblingClass = 'Normal' AND buildUpPlaySpeedClass = 'Balanced';
"""

team_att_and = pd.read_sql(query, conn)
team_att_and
# Out:
#        id buildUpPlayDribblingClass buildUpPlaySpeedClass
# 0       2                    Normal              Balanced
# 1       3                    Normal              Balanced
# 2       8                    Normal              Balanced
# 3       9                    Normal              Balanced
# 4      14                    Normal              Balanced
# ..    ...                       ...                   ...
# 382  1450                    Normal              Balanced
# 383  1451                    Normal              Balanced
# 384  1452                    Normal              Balanced
# 385  1457                    Normal              Balanced
# 386  1458                    Normal              Balanced
#
# [387 rows x 3 columns]

# %%
query = """
SELECT id, buildUpPlayPassingClass, buildUpPlaySpeedClass
FROM Team_Attributes
WHERE buildUpPlayPassingClass = 'Long' OR buildUpPlaySpeedClass = 'Fast';
"""

team_att_or = pd.read_sql(query, conn)
team_att_or
# Out:
#        id buildUpPlayPassingClass buildUpPlaySpeedClass
# 0       4                    Long                  Fast
# 1      42                    Long              Balanced
# 2      69                   Mixed                  Fast
# 3      72                   Mixed                  Fast
# 4      77                   Mixed                  Fast
# ..    ...                     ...                   ...
# 226  1420                   Mixed                  Fast
# 227  1421                    Long                  Fast
# 228  1423                    Long                  Fast
# 229  1436                    Long              Balanced
# 230  1437                    Long              Balanced
#
# [231 rows x 3 columns]

# %%
query = """
SELECT id, name
FROM Country
WHERE NOT name='Belgium';
"""

countries_not = pd.read_sql(query, conn)
countries_not
# Out:
#       id         name
# 0   1729      England
# 1   4769       France
# 2   7809      Germany
# 3  10257        Italy
# 4  13274  Netherlands
# 5  15722       Poland
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %%
query = """
SELECT id, name
FROM Country
WHERE name='Italy';
"""

countries_equal = pd.read_sql(query, conn)
countries_equal
# Out:
#       id   name
# 0  10257  Italy

# %%
query = """
SELECT id, name
FROM Country
WHERE name<>'Poland';
"""

countries_dif = pd.read_sql(query, conn)
countries_dif
# Out:
#       id         name
# 0      1      Belgium
# 1   1729      England
# 2   4769       France
# 3   7809      Germany
# 4  10257        Italy
# 5  13274  Netherlands
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %%
query = """
SELECT id, player_name, birthday, height, weight
FROM Player
WHERE weight BETWEEN 174 AND 176;
"""

players_weight = pd.read_sql(query, conn)
players_weight
# Out:
#          id            player_name             birthday  height  weight
# 0        17  Aaron Taylor-Sinclair  1991-04-08 00:00:00  182.88     176
# 1        34           Abdou Traore  1988-01-17 00:00:00  180.34     174
# 2        39           Abdoulaye Ba  1991-01-01 00:00:00  198.12     174
# 3        43       Abdoulaye Diallo  1992-03-30 00:00:00  187.96     174
# 4        61           Abel Aguilar  1985-01-06 00:00:00  185.42     176
# ...     ...                    ...                  ...     ...     ...
# 1180  11056      Zlatan Bajramovic  1979-08-12 00:00:00  182.88     174
# 1181  11058     Zlatan Ljubijankic  1983-12-15 00:00:00  185.42     176
# 1182  11065         Zoltan Szelesi  1981-11-22 00:00:00  182.88     176
# 1183  11072           Zsolt Laczko  1986-12-18 00:00:00  182.88     176
# 1184  11075     Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
# [1185 rows x 5 columns]

# %%
query = """
SELECT id, player_name, birthday, height, weight
FROM Player
WHERE player_name LIKE '%Messi%';
"""

players_messi = pd.read_sql(query, conn)
players_messi
# Out:
#      id   player_name             birthday  height  weight
# 0  6176  Lionel Messi  1987-06-24 00:00:00  170.18     159

# %%
query = """
SELECT id, name
FROM Country
ORDER BY name DESC;
"""

teams_orderdesc = pd.read_sql(query, conn)
teams_orderdesc
# Out:
#        id         name
# 0   24558  Switzerland
# 1   21518        Spain
# 2   19694     Scotland
# 3   17642     Portugal
# 4   15722       Poland
# 5   13274  Netherlands
# 6   10257        Italy
# 7    7809      Germany
# 8    4769       France
# 9    1729      England
# 10      1      Belgium

# %%
query = """
SELECT id, player_name, weight
FROM Player
ORDER BY weight ASC
LIMIT 15;
"""

player_weightasc = pd.read_sql(query, conn)
player_weightasc
# Out:
#        id            player_name  weight
# 0    5453             Juan Quero     117
# 1    6853        Mariusz Rybicki     121
# 2   10954        Yohandry Orozco     121
# 3    1480                Caetano     123
# 4    2612       Diego Buonanotte     123
# 5     317            Aldo Kalulu     126
# 6     655            Andre Horta     126
# 7    3446           Fouad Rachid     126
# 8    7258           Maxi Moralez     126
# 9    7264           Maxime Blanc     126
# 10   1111        Barry Nicholson     128
# 11   1824  Christopher Teichmann     128
# 12   3997        Gregory Lacombe     128
# 13   4316          Ibrahim Rabiu     128
# 14   5869            Koki Mizuno     128

# %%
query = """
SELECT id, player_name, height
FROM Player
ORDER BY height DESC
LIMIT 10;
"""

player_heightdesc = pd.read_sql(query, conn)
player_heightdesc
# Out:
#      id        player_name  height
# 0  5908   Kristof van Hout  208.28
# 1  1301       Bogdan Milic  203.20
# 2  1926  Costel Pantilimon  203.20
# 3  3274       Fejsal Mulic  203.20
# 4  5568      Jurgen Wevers  203.20
# 5  5804         Kevin Vink  203.20
# 6  5957      Lacina Traore  203.20
# 7  8016       Nikola Zigic  203.20
# 8  8285      Paolo Acerbis  203.20
# 9  8638      Pietro Marino  203.20

# %%
query = """
SELECT id, player_name, height
FROM (
  SELECT id, player_name, height
  FROM Player
  ORDER BY height DESC
  LIMIT 10
)
ORDER BY player_name DESC;
"""

player_height_name = pd.read_sql(query, conn)
player_height_name
# Out:
#      id        player_name  height
# 0  8638      Pietro Marino  203.20
# 1  8285      Paolo Acerbis  203.20
# 2  8016       Nikola Zigic  203.20
# 3  5957      Lacina Traore  203.20
# 4  5908   Kristof van Hout  208.28
# 5  5804         Kevin Vink  203.20
# 6  5568      Jurgen Wevers  203.20
# 7  3274       Fejsal Mulic  203.20
# 8  1926  Costel Pantilimon  203.20
# 9  1301       Bogdan Milic  203.20

# %%
#8.1.2
query = """
SELECT defencePressureClass, COUNT(id)
FROM Team_Attributes
GROUP BY defencePressureClass;
"""

teams_defence = pd.read_sql(query, conn)
teams_defence
# Out:
#   defencePressureClass  COUNT(id)
# 0                 Deep        154
# 1                 High         61
# 2               Medium       1243

# %%
query = """
SELECT season, COUNT(DISTINCT stage) AS number_of_stages, AVG(home_team_goal) AS avg_home_team_goals, AVG(away_team_goal ) AS avg_away_team_goals, home_team_goal+away_team_goal AS total_goals
FROM Match
GROUP BY season;
"""

stages_by_season = pd.read_sql(query, conn)
stages_by_season
# Out:
#       season  number_of_stages  avg_home_team_goals  avg_away_team_goals  \
# 0  2008/2009                38             1.505412             1.101924
# 1  2009/2010                38             1.541176             1.131269
# 2  2010/2011                38             1.548466             1.135276
# 3  2011/2012                38             1.572671             1.143789
# 4  2012/2013                38             1.550000             1.222699
# 5  2013/2014                38             1.578826             1.187995
# 6  2014/2015                38             1.520301             1.155489
# 7  2015/2016                38             1.543897             1.210764
#
#    total_goals
# 0            2
# 1            4
# 2            1
# 3            3
# 4            2
# 5            2
# 6            3
# 7            3

# %%
query = """
SELECT c.name AS country_name, COUNT(m.id) AS count_matches
FROM Match m
JOIN Country c ON m.country_id = c.id
WHERE m.season = '2008/2009' AND c.name IN ('Spain', 'Belgium')
GROUP BY c.name
ORDER BY count_matches DESC;
"""

country_matches = pd.read_sql(query, conn)
country_matches
# Out:
#   country_name  count_matches
# 0        Spain            380
# 1      Belgium            306

# %%
query = """
SELECT m.id AS match_id, c.name AS country_name, l.name AS league_name, m.season, m.stage, m.date, ht.team_long_name AS home_team, at.team_long_name AS away_team, m.home_team_goal, m.away_team_goal
FROM Match m
JOIN Country c ON m.country_id = c.id
JOIN League l ON m.league_id = l.id
JOIN Team ht ON m.home_team_api_id = ht.team_api_id
JOIN Team at ON m.away_team_api_id = at.team_api_id
WHERE c.name = 'Spain'
ORDER BY m.date ASC
LIMIT 10;
"""

detailed_matches = pd.read_sql(query, conn)
detailed_matches
# Out:
#    match_id country_name      league_name     season  stage  \
# 0     21518        Spain  Spain LIGA BBVA  2008/2009      1
# 1     21525        Spain  Spain LIGA BBVA  2008/2009      1
# 2     21519        Spain  Spain LIGA BBVA  2008/2009      1
# 3     21520        Spain  Spain LIGA BBVA  2008/2009      1
# 4     21521        Spain  Spain LIGA BBVA  2008/2009      1
# 5     21522        Spain  Spain LIGA BBVA  2008/2009      1
# 6     21523        Spain  Spain LIGA BBVA  2008/2009      1
# 7     21524        Spain  Spain LIGA BBVA  2008/2009      1
# 8     21526        Spain  Spain LIGA BBVA  2008/2009      1
# 9     21527        Spain  Spain LIGA BBVA  2008/2009      1
#
#                   date                  home_team        away_team  \
# 0  2008-08-30 00:00:00                Valencia CF     RCD Mallorca
# 1  2008-08-30 00:00:00               RCD Espanyol  Real Valladolid
# 2  2008-08-31 00:00:00                 CA Osasuna    Villarreal CF
# 3  2008-08-31 00:00:00  RC Deportivo de La Coruña   Real Madrid CF
# 4  2008-08-31 00:00:00                CD Numancia     FC Barcelona
# 5  2008-08-31 00:00:00           Racing Santander       Sevilla FC
# 6  2008-08-31 00:00:00     Real Sporting de Gijón        Getafe CF
# 7  2008-08-31 00:00:00        Real Betis Balompié    RC Recreativo
# 8  2008-08-31 00:00:00    Athletic Club de Bilbao       UD Almería
# 9  2008-08-31 00:00:00            Atlético Madrid        Málaga CF
#
#    home_team_goal  away_team_goal
# 0               3               0
# 1               1               0
# 2               1               1
# 3               2               1
# 4               1               0
# 5               1               1
# 6               1               2
# 7               0               1
# 8               1               3
# 9               4               0

# %%
query = """
SELECT
  c.name AS Country,
  l.name AS League,
  COUNT(DISTINCT m.stage) AS Stages,
  m.season AS Season,
  COUNT(DISTINCT ht.team_api_id) + COUNT(DISTINCT at.team_api_id) AS number_of_teams,
  ROUND(AVG(m.home_team_goal), 2) AS avg_local_goals,
  ROUND(AVG(m.away_team_goal), 2) AS avg_visitor_goals,
  ROUND((SUM(m.home_team_goal + m.away_team_goal) / COUNT(m.id)), 2) AS avg_goals,
  ROUND(AVG((m.home_team_goal - m.away_team_goal)), 2) AS avg_goal_dif,
  SUM(m.home_team_goal + m.away_team_goal) AS total_goals
FROM Match m
JOIN Country c ON m.country_id = c.id
JOIN League l ON m.league_id = l.id
JOIN Team ht ON m.home_team_api_id = ht.team_api_id
JOIN Team at ON m.away_team_api_id = at.team_api_id
WHERE c.name IN ('Spain', 'Germany', 'France', 'Italy', 'England')
GROUP BY c.name, l.name, m.season
HAVING ROUND((SUM(m.home_team_goal + m.away_team_goal) / COUNT(m.id)), 2) > 2.5;
"""

leages_by_season = pd.read_sql(query, conn)
leages_by_season
# Out:
#    Country                 League  Stages     Season  number_of_teams  \
# 0  Germany  Germany 1. Bundesliga      34  2013/2014               36
#
#    avg_local_goals  avg_visitor_goals  avg_goals  avg_goal_dif  total_goals
# 0             1.75               1.41        3.0          0.34          967

# %%
#10.1.3
query = """
SELECT
  c.name AS Country,
  l.name AS League,
  ht.team_long_name AS Team,
  COUNT(m.stage) AS Stages,
  m.season AS Season,
  SUM(m.home_team_goal) AS sum_goals,
  ROUND(AVG(m.home_team_goal), 2) AS avg_goals
FROM Match m
JOIN Country c ON m.country_id = c.id
JOIN League l ON m.league_id = l.id
JOIN Team ht ON m.home_team_api_id = ht.team_api_id
WHERE c.name IN ('Spain', 'Germany', 'England')
GROUP BY c.name, l.name, ht.team_long_name, m.season
HAVING SUM(m.home_team_goal) > 50
ORDER BY m.season DESC, sum_goals DESC;
"""

teams_by_season = pd.read_sql(query, conn)
teams_by_season
# Out:
#     Country                  League               Team  Stages     Season  \
# 0     Spain         Spain LIGA BBVA     Real Madrid CF      19  2015/2016
# 1     Spain         Spain LIGA BBVA       FC Barcelona      19  2015/2016
# 2   Germany   Germany 1. Bundesliga   FC Bayern Munich      17  2015/2016
# 3     Spain         Spain LIGA BBVA     Real Madrid CF      19  2014/2015
# 4     Spain         Spain LIGA BBVA       FC Barcelona      19  2014/2015
# 5     Spain         Spain LIGA BBVA       FC Barcelona      19  2013/2014
# 6   England  England Premier League    Manchester City      19  2013/2014
# 7     Spain         Spain LIGA BBVA     Real Madrid CF      19  2013/2014
# 8   England  England Premier League          Liverpool      19  2013/2014
# 9     Spain         Spain LIGA BBVA     Real Madrid CF      19  2012/2013
# 10    Spain         Spain LIGA BBVA       FC Barcelona      19  2012/2013
# 11  Germany   Germany 1. Bundesliga   FC Bayern Munich      17  2012/2013
# 12    Spain         Spain LIGA BBVA       FC Barcelona      19  2011/2012
# 13    Spain         Spain LIGA BBVA     Real Madrid CF      19  2011/2012
# 14  England  England Premier League    Manchester City      19  2011/2012
# 15  England  England Premier League  Manchester United      19  2011/2012
# 16    Spain         Spain LIGA BBVA     Real Madrid CF      19  2010/2011
# 17  England  England Premier League            Chelsea      19  2009/2010
# 18    Spain         Spain LIGA BBVA     Real Madrid CF      19  2009/2010
# 19    Spain         Spain LIGA BBVA       FC Barcelona      19  2009/2010
# 20  England  England Premier League  Manchester United      19  2009/2010
# 21    Spain         Spain LIGA BBVA       FC Barcelona      19  2008/2009
# 22  Germany   Germany 1. Bundesliga      VfL Wolfsburg      17  2008/2009
#
#     sum_goals  avg_goals
# 0          70       3.68
# 1          67       3.53
# 2          51       3.00
# 3          65       3.42
# 4          64       3.37
# 5          64       3.37
# 6          63       3.32
# 7          63       3.32
# 8          53       2.79
# 9          67       3.53
# 10         63       3.32
# 11         56       3.29
# 12         73       3.84
# 13         70       3.68
# 14         55       2.89
# 15         52       2.74
# 16         61       3.21
# 17         68       3.58
# 18         60       3.16
# 19         57       3.00
# 20         52       2.74
# 21         61       3.21
# 22         51       3.00

# %%
query = """
SELECT
  p.player_name,
  DATE(CURRENT_DATE) - p.birthday AS Age,
  pa.overall_rating,
  pa.potential,
  pa.date AS RatingDate
FROM Player p
JOIN Player_Attributes pa ON p.player_api_id = pa.player_api_id
WHERE p.player_name = 'Cristiano Ronaldo'
ORDER BY Age;
"""

ratingCristiano = pd.read_sql(query, conn)
ratingCristiano
# Out:
#           player_name  Age  overall_rating  potential           RatingDate
# 0   Cristiano Ronaldo   39              93         93  2015-10-16 00:00:00
# 1   Cristiano Ronaldo   39              93         93  2015-09-25 00:00:00
# 2   Cristiano Ronaldo   39              93         93  2015-09-21 00:00:00
# 3   Cristiano Ronaldo   39              92         92  2015-05-15 00:00:00
# 4   Cristiano Ronaldo   39              92         92  2015-04-17 00:00:00
# 5   Cristiano Ronaldo   39              92         92  2014-10-31 00:00:00
# 6   Cristiano Ronaldo   39              92         92  2014-09-18 00:00:00
# 7   Cristiano Ronaldo   39              92         92  2014-02-07 00:00:00
# 8   Cristiano Ronaldo   39              92         95  2014-01-17 00:00:00
# 9   Cristiano Ronaldo   39              92         95  2013-09-20 00:00:00
# 10  Cristiano Ronaldo   39              92         95  2013-03-22 00:00:00
# 11  Cristiano Ronaldo   39              92         95  2013-03-08 00:00:00
# 12  Cristiano Ronaldo   39              92         94  2013-03-01 00:00:00
# 13  Cristiano Ronaldo   39              92         94  2013-02-15 00:00:00
# 14  Cristiano Ronaldo   39              92         94  2012-08-31 00:00:00
# 15  Cristiano Ronaldo   39              92         94  2012-02-22 00:00:00
# 16  Cristiano Ronaldo   39              92         94  2011-08-30 00:00:00
# 17  Cristiano Ronaldo   39              89         93  2011-02-22 00:00:00
# 18  Cristiano Ronaldo   39              89         94  2010-08-30 00:00:00
# 19  Cristiano Ronaldo   39              89         93  2010-02-22 00:00:00
# 20  Cristiano Ronaldo   39              89         94  2009-08-30 00:00:00
# 21  Cristiano Ronaldo   39              90         94  2009-02-22 00:00:00
# 22  Cristiano Ronaldo   39              91         94  2008-08-30 00:00:00
# 23  Cristiano Ronaldo   39              91         94  2007-08-30 00:00:00
# 24  Cristiano Ronaldo   39              87         92  2007-02-22 00:00:00

# %%
query = """
SELECT *
FROM Player;
"""

country_matches = pd.read_sql(query, conn)
country_matches
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# 2      1991-05-13 00:00:00  170.18     163
# 3      1982-05-08 00:00:00  182.88     198
# 4      1979-11-08 00:00:00  182.88     154
# ...                    ...     ...     ...
# 11055  1979-04-03 00:00:00  182.88     168
# 11056  1986-12-18 00:00:00  182.88     176
# 11057  1979-04-29 00:00:00  180.34     154
# 11058  1981-10-06 00:00:00  185.42     172
# 11059  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 7 columns]
